# %% [markdown]
# <a href="https://colab.research.google.com/github/AngelaDuran/Coordinates_In_yolov5/blob/main/LabCoordinatesYOLOv5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Please run each cell in order (some cells you may run multiple times)**

# %% [markdown]
# **To Run different experiement go to: "Runtime" then "Disconnect and Delete Runtime"**

# %% [markdown]
# If you see 🐢(turtle), please slow down and modify the cell beneath it as instructed!

# %% [markdown]
# For questions on this notebook email Angela (angeladuran.py@gmail.com)

# %%
# !git clone https://github.com/AngelaDuran/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v6.1-318-gd802a2a Python-3.7.13 torch-1.11.0+cu102 CPU
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 40.7/107.7 GB disk)

# %%
# %cd data
# %mkdir labImages
# %cd labImages
# Out:
# /content/yolov5/data
# /content/yolov5/data/labImages

# %%
# use this to upload files
def upload():
  from google.colab import files
  uploaded = files.upload() 
  for name, data in uploaded.items():
    with open(name, 'wb') as f:
      f.write(data)
      print ('saved file', name)

#use this function to display image
def imgShow(path):
  import cv2
  import matplotlib.pyplot as plt
  # %matplotlib inline

  image = cv2.imread(path)
  height, width = image.shape[:2]
  resized_image = cv2.resize(image,(3*width, 3*height), interpolation = cv2.INTER_CUBIC)

  fig = plt.gcf()
  fig.set_size_inches(18, 10)
  plt.axis("off")
  plt.imshow(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
  plt.show()

  #use this function to download files
  # use this to download a file  
def download(path):
  from google.colab import files
  files.download(path)

# %%
# Out:
# Please enteradfa
# 'adfa'

# %% [markdown]
# 🐢

# %%
#Re run this cell as many times as you need to upload
upload()
# Out:
#      <input type="file" id="files-8b0bcd2a-a76d-4177-94c3-308bdab60c29" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8b0bcd2a-a76d-4177-94c3-308bdab60c29">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving test4.jpg to test4.jpg
# saved file test4.jpg

# %%
# %cd ../..
# Out:
# /content/yolov5

# %% [markdown]
# **THIS BELLOW CELL PERFORMS CALCULATIONS, WILL DISPLAY CENTER PIXEL COORDINATES**

# %%
# !python detect.py --weights yolov5s.pt --img 640 --conf 0.25 --source data/labImages
# Out:
# detect: weights=['yolov5s.pt'], source=data/labImages, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-317-g21c1fd9 Python-3.7.13 torch-1.11.0+cu102 CPU
#
# ...
# 100% 14.1M/14.1M [00:00<00:00, 36.8MB/s]
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# banana 0.25
# (1538, 488)
# orange 0.33
# (1550, 698)
# tv 0.33
# (145, 317)
# cup 0.38
# (1260, 549)
# banana 0.39
# (1378, 670)
# apple 0.66
# (1551, 695)
# person 0.76
# (1019, 482)
# orange 0.85
# (1876, 837)
# video 1/1 (1/253) /content/yolov5/data/labImages/FruitVid.mp4: 384x640 1 person, 1 cup, 2 bananas, 1 apple, 2 oranges, 1 tv, Done. (0.273s)
# ...

# %% [markdown]
# 🐢

# %%
#copy path printed from above: "Results saved to runs/detect/[expFile]/fileName.jpg" and specify which image you want to display
#copy the bellow line multiple times for multiple images
imgShow('runs/detect/exp/imgQuadFull.jpg')

# %% [markdown]
# 🐢

# %%
#Re reun this cell to download all desired images
#Change image name
download('runs/detect/exp2/IMG_NAME_HERE.jpg')

# %%
data = {
    #Item: [xL, xR, yL, yR]
    'Orange': [20,200, 300, 450],
    'Apple': [100, 150, 320, 900]
}
